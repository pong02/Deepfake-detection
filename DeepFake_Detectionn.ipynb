# %% [markdown]
# <a href="https://colab.research.google.com/github/Stuti1998/Deepfake-detection/blob/master/DeepFake_Detectionn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DeepFake Detection using Eye blinking
# -Stuti Kuvadia (17IT047)

# %%
# %cd /content/ 
# !git clone https://github.com/Stuti1998/Deepfake-detection
import warnings
warnings.filterwarnings('ignore')
# Out:
# /content
# Cloning into 'Deepfake-detection'...
# remote: Enumerating objects: 121, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 121 (delta 2), reused 0 (delta 0), pack-reused 111
# Receiving objects: 100% (121/121), 71.07 MiB | 30.37 MiB/s, done.
# Resolving deltas: 100% (31/31), done.

# %%
# %cd /content/Deepfake-detection
# !pip install -r requirements.txt
# Out:
# /content/Deepfake-detection
# Requirement already satisfied: pyyaml==3.12 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (3.12)
# Requirement already satisfied: opencv-python==3.4.2.17 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (3.4.2.17)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python==3.4.2.17->-r requirements.txt (line 2)) (1.19.5)

# %%
# %cd /content/Deepfake-detection
# !gdown --id 1NJ160vkLq8JCVTZC8ocsDD8VfFskDSRM
# !gdown --id 1OJZ4mvZefwMJ7Knpsf_RFhCsA4xbAOMc
# %cd /content/Deepfake-detection/toy
# !gdown --id 11a7QGXwMyL_fzVgK9n8BI1QT-36tgr3Z
# !gdown --id 1-V_ZFTr6sdbL8ZhV6j_GgikLFEPM8Q4A
# %cd ..
# Out:
# /content/deefakedetection/toy
# Downloading...
# From: https://drive.google.com/uc?id=1-V_ZFTr6sdbL8ZhV6j_GgikLFEPM8Q4A
# To: /content/deefakedetection/toy/183.mp4
# 87.1MB [00:00, 101MB/s]
# /content/deefakedetection

# %%
# %cd /content/Deepfake-detection
# !unzip /content/deefakedetection/ckpt_CNN.zip 
# !unzip /content/deefakedetection/ckpt_LRCN.zip
# Out:
# /content/deefakedetection
# Archive:  /content/deefakedetection/ckpt_CNN.zip
#    creating: ckpt_CNN/
#   inflating: ckpt_CNN/model.ckpt.index
#   inflating: ckpt_CNN/model.ckpt.data-00000-of-00001
#   inflating: ckpt_CNN/model.ckpt.meta
# Archive:  /content/deefakedetection/ckpt_LRCN.zip
#    creating: ckpt_LRCN/
#   inflating: ckpt_LRCN/model.ckpt.index
#   inflating: ckpt_LRCN/model.ckpt.data-00000-of-00001
#   inflating: ckpt_LRCN/model.ckpt.meta

# %%
# %tensorflow_version 1.x
# %cd /content/Deepfake-detection/toy/
# !python run_cnn.py --input_vid_path=/content/Deepfake-detection/toy/183.mp4 --out_dir=/content/Deepfake-detection/toy/
# Out:
# /content/Deepfake-detection/toy
# Parsing video /content/Deepfake-detection/toy/183.mp4
# Eye blinking solution is building...
# face aligning...
# 100% 390/390 [01:07<00:00,  5.74it/s]
# WARNING:tensorflow:From ../blink_net.py:37: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From ../deep_base/ops.py:39: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From ../deep_base/ops.py:41: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# conv1_1 weights: <tf.Variable 'conv1_1/weights:0' shape=(3, 3, 3, 64) dtype=float32_ref>, bias: <tf.Variable 'conv1_1/biases:0' shape=(64,) dtype=float32_ref>, out: Tensor("conv1_1/BiasAdd:0", shape=(?, 224, 224, 64), dtype=float32)
# conv1_2 weights: <tf.Variable 'conv1_2/weights:0' shape=(3, 3, 64, 64) dtype=float32_ref>, bias: <tf.Variable 'conv1_2/biases:0' shape=(64,) dtype=float32_ref>, out: Tensor("conv1_2/BiasAdd:0", shape=(?, 224, 224, 64), dtype=float32)
# WARNING:tensorflow:From ../deep_base/ops.py:77: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# pool1 max pool out: Tensor("pool1/MaxPool:0", shape=(?, 112, 112, 64), dtype=float32)
# conv2_1 weights: <tf.Variable 'conv2_1/weights:0' shape=(3, 3, 64, 128) dtype=float32_ref>, bias: <tf.Variable 'conv2_1/biases:0' shape=(128,) dtype=float32_ref>, out: Tensor("conv2_1/BiasAdd:0", shape=(?, 112, 112, 128), dtype=float32)
# conv2_2 weights: <tf.Variable 'conv2_2/weights:0' shape=(3, 3, 128, 128) dtype=float32_ref>, bias: <tf.Variable 'conv2_2/biases:0' shape=(128,) dtype=float32_ref>, out: Tensor("conv2_2/BiasAdd:0", shape=(?, 112, 112, 128), dtype=float32)
# pool2 max pool out: Tensor("pool2/MaxPool:0", shape=(?, 56, 56, 128), dtype=float32)
# conv3_1 weights: <tf.Variable 'conv3_1/weights:0' shape=(3, 3, 128, 256) dtype=float32_ref>, bias: <tf.Variable 'conv3_1/biases:0' shape=(256,) dtype=float32_ref>, out: Tensor("conv3_1/BiasAdd:0", shape=(?, 56, 56, 256), dtype=float32)
# conv3_2 weights: <tf.Variable 'conv3_2/weights:0' shape=(3, 3, 256, 256) dtype=float32_ref>, bias: <tf.Variable 'conv3_2/biases:0' shape=(256,) dtype=float32_ref>, out: Tensor("conv3_2/BiasAdd:0", shape=(?, 56, 56, 256), dtype=float32)
# conv3_3 weights: <tf.Variable 'conv3_3/weights:0' shape=(3, 3, 256, 256) dtype=float32_ref>, bias: <tf.Variable 'conv3_3/biases:0' shape=(256,) dtype=float32_ref>, out: Tensor("conv3_3/BiasAdd:0", shape=(?, 56, 56, 256), dtype=float32)
# pool3 max pool out: Tensor("pool3/MaxPool:0", shape=(?, 28, 28, 256), dtype=float32)
# conv4_1 weights: <tf.Variable 'conv4_1/weights:0' shape=(3, 3, 256, 512) dtype=float32_ref>, bias: <tf.Variable 'conv4_1/biases:0' shape=(512,) dtype=float32_ref>, out: Tensor("conv4_1/BiasAdd:0", shape=(?, 28, 28, 512), dtype=float32)
# conv4_2 weights: <tf.Variable 'conv4_2/weights:0' shape=(3, 3, 512, 512) dtype=float32_ref>, bias: <tf.Variable 'conv4_2/biases:0' shape=(512,) dtype=float32_ref>, out: Tensor("conv4_2/BiasAdd:0", shape=(?, 28, 28, 512), dtype=float32)
# conv4_3 weights: <tf.Variable 'conv4_3/weights:0' shape=(3, 3, 512, 512) dtype=float32_ref>, bias: <tf.Variable 'conv4_3/biases:0' shape=(512,) dtype=float32_ref>, out: Tensor("conv4_3/BiasAdd:0", shape=(?, 28, 28, 512), dtype=float32)
# pool4 max pool out: Tensor("pool4/MaxPool:0", shape=(?, 14, 14, 512), dtype=float32)
# conv5_1 weights: <tf.Variable 'conv5_1/weights:0' shape=(3, 3, 512, 512) dtype=float32_ref>, bias: <tf.Variable 'conv5_1/biases:0' shape=(512,) dtype=float32_ref>, out: Tensor("conv5_1/BiasAdd:0", shape=(?, 14, 14, 512), dtype=float32)
# conv5_2 weights: <tf.Variable 'conv5_2/weights:0' shape=(3, 3, 512, 512) dtype=float32_ref>, bias: <tf.Variable 'conv5_2/biases:0' shape=(512,) dtype=float32_ref>, out: Tensor("conv5_2/BiasAdd:0", shape=(?, 14, 14, 512), dtype=float32)
# conv5_3 weights: <tf.Variable 'conv5_3/weights:0' shape=(3, 3, 512, 512) dtype=float32_ref>, bias: <tf.Variable 'conv5_3/biases:0' shape=(512,) dtype=float32_ref>, out: Tensor("conv5_3/BiasAdd:0", shape=(?, 14, 14, 512), dtype=float32)
# pool5 max pool out: Tensor("pool5/MaxPool:0", shape=(?, 7, 7, 512), dtype=float32)
# fc6 weights: <tf.Variable 'fc6/weights:0' shape=(25088, 4096) dtype=float32_ref>, bias: <tf.Variable 'fc6/biases:0' shape=(4096,) dtype=float32_ref>, out: Tensor("fc6/BiasAdd:0", shape=(?, 4096), dtype=float32)
# fc7 weights: <tf.Variable 'fc7/weights:0' shape=(4096, 4096) dtype=float32_ref>, bias: <tf.Variable 'fc7/biases:0' shape=(4096,) dtype=float32_ref>, out: Tensor("fc7/BiasAdd:0", shape=(?, 4096), dtype=float32)
# fc8 weights: <tf.Variable 'fc8/weights:0' shape=(4096, 2) dtype=float32_ref>, bias: <tf.Variable 'fc8/biases:0' shape=(2,) dtype=float32_ref>, out: Tensor("fc8/BiasAdd:0", shape=(?, 2), dtype=float32)
# WARNING:tensorflow:From ../blink_net.py:41: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From run_cnn.py:22: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-04-28 19:08:37.369222: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-04-28 19:08:37.405138: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-28 19:08:37.405799: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2021-04-28 19:08:37.406138: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-04-28 19:08:37.406216: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-04-28 19:08:37.407675: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-04-28 19:08:37.407754: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-04-28 19:08:37.407795: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-04-28 19:08:37.408459: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-04-28 19:08:37.408537: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-04-28 19:08:37.408642: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-28 19:08:37.409255: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-28 19:08:37.409801: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-04-28 19:08:37.414181: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2021-04-28 19:08:37.414381: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55ca54260540 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-04-28 19:08:37.414410: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-04-28 19:08:37.524085: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-28 19:08:37.524908: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55ca54260700 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-04-28 19:08:37.524946: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2021-04-28 19:08:37.525138: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-28 19:08:37.525786: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2021-04-28 19:08:37.525871: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-04-28 19:08:37.525901: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-04-28 19:08:37.525931: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-04-28 19:08:37.525954: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-04-28 19:08:37.525974: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-04-28 19:08:37.525997: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-04-28 19:08:37.526019: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-04-28 19:08:37.526101: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-28 19:08:37.526751: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-28 19:08:37.527305: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-04-28 19:08:37.527382: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-04-28 19:08:37.528826: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-04-28 19:08:37.528856: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-04-28 19:08:37.528876: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-04-28 19:08:37.529009: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-28 19:08:37.529675: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-28 19:08:37.530242: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-04-28 19:08:37.530285: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14257 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# WARNING:tensorflow:From ../solver.py:44: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From ../solver.py:59: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# Loading failed.
# Frame: 0
# 2021-04-28 19:08:38.064534: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-04-28 19:08:38.311540: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 1
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 2
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 3
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 4
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 5
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 6
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 7
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 8
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 9
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 10
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 11
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 12
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 13
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 14
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 15
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 16
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 17
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 18
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 19
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 20
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 21
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 22
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 23
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 24
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 25
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 26
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 27
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 28
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 29
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 30
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 31
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: 32
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Frame: