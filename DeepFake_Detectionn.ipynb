# %% [markdown]
# <a href="https://colab.research.google.com/github/Stuti1998/Deepfake-detection/blob/master/DeepFake_Detectionn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DeepFake Detection using Eye blinking
# -Stuti Kuvadia (17IT047)

# %%
# %cd /content/ 
# !git clone https://github.com/Stuti1998/Deepfake-detection
import warnings
warnings.filterwarnings('ignore')
# Out:
# /content
# Cloning into 'Deepfake-detection'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 134 (delta 7), reused 0 (delta 0), pack-reused 111
# Receiving objects: 100% (134/134), 71.08 MiB | 34.06 MiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %%
# %cd /content/Deepfake-detection
# !pip install -r requirements.txt
# Out:
# /content/Deepfake-detection
# ...
#      |████████████████████████████████| 256kB 21.4MB/s
# ...
#      |████████████████████████████████| 25.0MB 1.4MB/s
# ...
#   Created wheel for pyyaml: filename=PyYAML-3.12-cp37-cp37m-linux_x86_64.whl size=43059 sha256=e79edd8b0e4802030b5069027082fae62c99254478597f4c5b71f992b43ee50c
#   Stored in directory: /root/.cache/pip/wheels/03/05/65/bdc14f2c6e09e82ae3e0f13d021e1b6b2481437ea2f207df3f
# Successfully built pyyaml
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# ...

# %%
# %cd /content/Deepfake-detection
# !gdown --id 1NJ160vkLq8JCVTZC8ocsDD8VfFskDSRM
# !gdown --id 1OJZ4mvZefwMJ7Knpsf_RFhCsA4xbAOMc
# %cd /content/Deepfake-detection/toy
# !gdown --id 11a7QGXwMyL_fzVgK9n8BI1QT-36tgr3Z
# !gdown --id 1-V_ZFTr6sdbL8ZhV6j_GgikLFEPM8Q4A
# %cd ..
# Out:
# /content/Deepfake-detection
# Downloading...
# From: https://drive.google.com/uc?id=1NJ160vkLq8JCVTZC8ocsDD8VfFskDSRM
# To: /content/Deepfake-detection/ckpt_CNN.zip
# 495MB [00:03, 145MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1OJZ4mvZefwMJ7Knpsf_RFhCsA4xbAOMc
# To: /content/Deepfake-detection/ckpt_LRCN.zip
# 450MB [00:03, 125MB/s]
# /content/Deepfake-detection/toy
# Downloading...
# From: https://drive.google.com/uc?id=11a7QGXwMyL_fzVgK9n8BI1QT-36tgr3Z
# To: /content/Deepfake-detection/toy/183_253.mp4
# 89.9MB [00:00, 135MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-V_ZFTr6sdbL8ZhV6j_GgikLFEPM8Q4A
# To: /content/Deepfake-detection/toy/183.mp4
# 87.1MB [00:00, 154MB/s]
# /content/Deepfake-detection

# %%
# %cd /content/Deepfake-detection
# !unzip /content/Deepfake-detection/ckpt_CNN.zip 
# !unzip /content/Deepfake-detection/ckpt_LRCN.zip
# Out:
# /content/Deepfake-detection
# Archive:  /content/Deepfake-detection/ckpt_CNN.zip
#    creating: ckpt_CNN/
#   inflating: ckpt_CNN/model.ckpt.index
#   inflating: ckpt_CNN/model.ckpt.data-00000-of-00001
#   inflating: ckpt_CNN/model.ckpt.meta
# Archive:  /content/Deepfake-detection/ckpt_LRCN.zip
#    creating: ckpt_LRCN/
#   inflating: ckpt_LRCN/model.ckpt.index
#   inflating: ckpt_LRCN/model.ckpt.data-00000-of-00001
#   inflating: ckpt_LRCN/model.ckpt.meta

# %%
# %tensorflow_version 1.x
# %cd /content/Deepfake-detection/toy/
# !python run_cnn.py --input_vid_path=/content/Deepfake-detection/toy/183.mp4 --out_dir=/content/Deepfake-detection/toy/
# Out:
# /content/Deepfake-detection/toy
# Parsing video /content/Deepfake-detection/toy/183.mp4
# Eye blinking solution is building...
# face aligning...
# 100% 390/390 [01:07<00:00,  5.76it/s]
# WARNING:tensorflow:From ../blink_net.py:37: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From ../deep_base/ops.py:39: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From ../deep_base/ops.py:41: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# conv1_1 weights: <tf.Variable 'conv1_1/weights:0' shape=(3, 3, 3, 64) dtype=float32_ref>, bias: <tf.Variable 'conv1_1/biases:0' shape=(64,) dtype=float32_ref>, out: Tensor("conv1_1/BiasAdd:0", shape=(?, 224, 224, 64), dtype=float32)
# ...

# %%
# %cd /content/Deepfake-detection/toy/
# !python run_cnn.py --input_vid_path=/content/Deepfake-detection/toy/183_253.mp4 --out_dir=/content/Deepfake-detection/toy/
# Out:
# /content/Deepfake-detection/toy
# Parsing video /content/Deepfake-detection/toy/183_253.mp4
# Eye blinking solution is building...
# face aligning...
# 100% 390/390 [01:00<00:00,  6.42it/s]
# WARNING:tensorflow:From ../blink_net.py:37: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From ../deep_base/ops.py:39: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From ../deep_base/ops.py:41: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# conv1_1 weights: <tf.Variable 'conv1_1/weights:0' shape=(3, 3, 3, 64) dtype=float32_ref>, bias: <tf.Variable 'conv1_1/biases:0' shape=(64,) dtype=float32_ref>, out: Tensor("conv1_1/BiasAdd:0", shape=(?, 224, 224, 64), dtype=float32)
# ...
